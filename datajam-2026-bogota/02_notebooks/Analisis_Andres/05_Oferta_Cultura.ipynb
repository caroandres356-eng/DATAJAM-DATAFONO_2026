# %% [markdown]
# # 🎭 5. Centros Culturales (OTRA OFERTA INSTITUCIONAL)
#
# 👉 Complementa el deporte (bienestar social) y nos permite ver el mapa de acceso cultural de los jóvenes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ### Carga de Datos Preprocesados

# %%
PROCESSED_DIR = '../../01_datos/processed'
file_path = os.path.join(PROCESSED_DIR, 'p_centros_culturales_bogota_limpio.xlsx')

if os.path.exists(file_path):
    df_cultura = pd.read_excel(file_path)
    print(f'Total de registros cargados: {len(df_cultura):,}')
    display(df_cultura.head(3))
else:
    print('El archivo de Cultura procesado no fue encontrado.')

# %% [markdown]
# ## 📍 Cobertura y 📊 Densidad
# **¿Dónde están concentrados? ¿Cuántos centros por localidad?**

# %%
if 'localidad' in df_cultura.columns:
    densidad = df_cultura['localidad'].value_counts()
    plt.figure(figsize=(10,7))
    sns.barplot(x=densidad.values, y=densidad.index, palette='husl')
    plt.title('Densidad de Centros Culturales por Localidad')
    plt.xlabel('Número de Centros')
    plt.ylabel('Localidad')
    plt.show()

# %% [markdown]
# ## 🧭 Distribución
# **¿Hay zonas sin acceso? (Lagunas culturales)**

# %%
if 'localidad' in df_cultura.columns:
    # Evaluamos qué localidades tienen menos de 5 centros culturales
    baja_cobertura = densidad[densidad <= 5]
    print('⚠️ Zonas con riesgo crítico por baja cobertura cultural:\n', baja_cobertura)
    
    if 'upz' in df_cultura.columns:
        print('\nTotal de UPZs impactadas culturalmente:', df_cultura['upz'].nunique(), 'de 117 posibles.')
